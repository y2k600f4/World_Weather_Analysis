# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)# Assemble the OpenWeatherMap's API call

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
             
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":description })
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | new norfolk
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | kaitangata
# Processing Record 7 of Set 1 | sorland
# Processing Record 8 of Set 1 | port blair
# Processing Record 9 of Set 1 | naryan-mar
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | isangel
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | westport
# Processing Record 15 of Set 1 | campoverde
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | tasiilaq
# Processing Record 18 of Set 1 | airai
# Processing Record 19 of Set 1 | adrar
# Processing Record 20 of Set 1 | aksarka
# Processing Record 21 of Set 1 | meulaboh
# Processing Record 22 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 1 | souillac
# Processing Record 24 of Set 1 | necochea
# Processing Record 25 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 26 of Set 1 | benjamin constant
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | ayan
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | bredasdorp
# Processing Record 33 of Set 1 | ketchikan
# Processing Record 34 of Set 1 | mvuma
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | karpenision
# City not found. Skipping...
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | coquimbo
# Processing Record 39 of Set 1 | camargo
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | staryy nadym
# Processing Record 42 of Set 1 | iqaluit
# Processing Record 43 of Set 1 | port charlotte
# Processing Record 44 of Set 1 | atuona
# Processing Record 45 of Set 1 | shu
# Processing Record 46 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | kodiak
# Processing Record 49 of Set 1 | winfield
# Processing Record 50 of Set 1 | springbok
# Processing Record 1 of Set 2 | bluff
# Processing Record 2 of Set 2 | cabo san lucas
# Processing Record 3 of Set 2 | carnarvon
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | el roble
# Processing Record 6 of Set 2 | karratha
# Processing Record 7 of Set 2 | plouzane
# Processing Record 8 of Set 2 | sinnamary
# Processing Record 9 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 2 | pisco
# Processing Record 11 of Set 2 | savinka
# Processing Record 12 of Set 2 | boguchany
# Processing Record 13 of Set 2 | mayo
# Processing Record 14 of Set 2 | saint-philippe
# Processing Record 15 of Set 2 | richards bay
# Processing Record 16 of Set 2 | ribeira grande
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | kalaikunda
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | mao
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | sirnak
# Processing Record 23 of Set 2 | klyuchi
# Processing Record 24 of Set 2 | chabahar
# Processing Record 25 of Set 2 | kununurra
# Processing Record 26 of Set 2 | ossora
# Processing Record 27 of Set 2 | qaanaaq
# Processing Record 28 of Set 2 | pasighat
# Processing Record 29 of Set 2 | taksimo
# Processing Record 30 of Set 2 | khatanga
# Processing Record 31 of Set 2 | upernavik
# Processing Record 32 of Set 2 | garowe
# Processing Record 33 of Set 2 | reftinskiy
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | la ronge
# Processing Record 36 of Set 2 | ntchisi
# Processing Record 37 of Set 2 | kristiinankaupunki
# Processing Record 38 of Set 2 | saryg-sep
# Processing Record 39 of Set 2 | swan hill
# Processing Record 40 of Set 2 | san ramon
# Processing Record 41 of Set 2 | yulara
# Processing Record 42 of Set 2 | pangnirtung
# Processing Record 43 of Set 2 | banda aceh
# Processing Record 44 of Set 2 | portland
# Processing Record 45 of Set 2 | saint-paul
# Processing Record 46 of Set 2 | klaksvik
# Processing Record 47 of Set 2 | ban nahin
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | caravelas
# Processing Record 50 of Set 2 | catuday
# Processing Record 1 of Set 3 | lasa
# Processing Record 2 of Set 3 | vangaindrano
# Processing Record 3 of Set 3 | vao
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | jumla
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | puerto carreno
# Processing Record 8 of Set 3 | campbellsville
# Processing Record 9 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 3 | saskylakh
# Processing Record 11 of Set 3 | vaini
# Processing Record 12 of Set 3 | morehead
# Processing Record 13 of Set 3 | kokoda
# Processing Record 14 of Set 3 | punta arenas
# Processing Record 15 of Set 3 | winneba
# Processing Record 16 of Set 3 | mount isa
# Processing Record 17 of Set 3 | teacapan
# Processing Record 18 of Set 3 | jennings
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | krasnoselkup
# Processing Record 21 of Set 3 | lorengau
# Processing Record 22 of Set 3 | antofagasta
# Processing Record 23 of Set 3 | goderich
# Processing Record 24 of Set 3 | mezen
# Processing Record 25 of Set 3 | launceston
# Processing Record 26 of Set 3 | vardo
# Processing Record 27 of Set 3 | logan
# Processing Record 28 of Set 3 | sines
# Processing Record 29 of Set 3 | east london
# Processing Record 30 of Set 3 | koungou
# Processing Record 31 of Set 3 | kavaratti
# Processing Record 32 of Set 3 | ponta do sol
# Processing Record 33 of Set 3 | san cristobal
# Processing Record 34 of Set 3 | blagoyevo
# Processing Record 35 of Set 3 | asau
# Processing Record 36 of Set 3 | chapais
# Processing Record 37 of Set 3 | guerrero negro
# Processing Record 38 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 3 | barrow
# Processing Record 40 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 41 of Set 3 | pevek
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | maniitsoq
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | itoman
# Processing Record 46 of Set 3 | burns lake
# Processing Record 47 of Set 3 | cayenne
# Processing Record 48 of Set 3 | kavieng
# Processing Record 49 of Set 3 | bambous virieux
# Processing Record 50 of Set 3 | medicine hat
# Processing Record 1 of Set 4 | outlook
# Processing Record 2 of Set 4 | lake city
# Processing Record 3 of Set 4 | rawson
# Processing Record 4 of Set 4 | zeya
# Processing Record 5 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 4 | kapaa
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | nabire
# Processing Record 9 of Set 4 | pacific grove
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 4 | udon thani
# Processing Record 12 of Set 4 | houston
# Processing Record 13 of Set 4 | say
# Processing Record 14 of Set 4 | punta alta
# Processing Record 15 of Set 4 | the pas
# Processing Record 16 of Set 4 | bahir dar
# Processing Record 17 of Set 4 | lakes entrance
# Processing Record 18 of Set 4 | kamenka
# Processing Record 19 of Set 4 | kutum
# Processing Record 20 of Set 4 | lewisporte
# Processing Record 21 of Set 4 | atar
# Processing Record 22 of Set 4 | cherskiy
# Processing Record 23 of Set 4 | san jose de guanipa
# Processing Record 24 of Set 4 | vila franca do campo
# Processing Record 25 of Set 4 | zolotinka
# City not found. Skipping...
# Processing Record 26 of Set 4 | arraial do cabo
# Processing Record 27 of Set 4 | batagay-alyta
# Processing Record 28 of Set 4 | robertson
# Processing Record 29 of Set 4 | matay
# Processing Record 30 of Set 4 | sasebo
# Processing Record 31 of Set 4 | haapiti
# Processing Record 32 of Set 4 | kroya
# Processing Record 33 of Set 4 | partizanskoye
# Processing Record 34 of Set 4 | rivera
# Processing Record 35 of Set 4 | mayskiy
# Processing Record 36 of Set 4 | vestmannaeyjar
# Processing Record 37 of Set 4 | hanzhong
# Processing Record 38 of Set 4 | qujing
# Processing Record 39 of Set 4 | bethel
# Processing Record 40 of Set 4 | soyo
# Processing Record 41 of Set 4 | ebano
# City not found. Skipping...
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | ligayan
# Processing Record 44 of Set 4 | leeton
# Processing Record 45 of Set 4 | kargasok
# Processing Record 46 of Set 4 | yaan
# Processing Record 47 of Set 4 | esperance
# Processing Record 48 of Set 4 | salinas
# Processing Record 49 of Set 4 | hanko
# Processing Record 50 of Set 4 | egersund
# Processing Record 1 of Set 5 | yar-sale
# Processing Record 2 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 5 | leningradskiy
# Processing Record 4 of Set 5 | sibolga
# Processing Record 5 of Set 5 | avera
# Processing Record 6 of Set 5 | el escorial
# Processing Record 7 of Set 5 | arnedo
# Processing Record 8 of Set 5 | dinsor
# City not found. Skipping...
# Processing Record 9 of Set 5 | mweka
# Processing Record 10 of Set 5 | imbituba
# Processing Record 11 of Set 5 | krasnovishersk
# Processing Record 12 of Set 5 | bolshaya irba
# City not found. Skipping...
# Processing Record 13 of Set 5 | coeneo
# Processing Record 14 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 5 | waverly
# Processing Record 16 of Set 5 | clarence town
# Processing Record 17 of Set 5 | tuatapere
# Processing Record 18 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 5 | ilulissat
# Processing Record 20 of Set 5 | mar del plata
# Processing Record 21 of Set 5 | cockburn town
# Processing Record 22 of Set 5 | abu dhabi
# Processing Record 23 of Set 5 | belaya gora
# Processing Record 24 of Set 5 | port hedland
# Processing Record 25 of Set 5 | ampanihy
# Processing Record 26 of Set 5 | hervey bay
# Processing Record 27 of Set 5 | ust-maya
# Processing Record 28 of Set 5 | york
# Processing Record 29 of Set 5 | longyearbyen
# Processing Record 30 of Set 5 | nuradilovo
# Processing Record 31 of Set 5 | kulhudhuffushi
# Processing Record 32 of Set 5 | san policarpo
# Processing Record 33 of Set 5 | maymyo
# Processing Record 34 of Set 5 | kirakira
# Processing Record 35 of Set 5 | danjiangkou
# Processing Record 36 of Set 5 | talnakh
# Processing Record 37 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 5 | the valley
# Processing Record 39 of Set 5 | tongling
# Processing Record 40 of Set 5 | terryville
# Processing Record 41 of Set 5 | salinopolis
# Processing Record 42 of Set 5 | darnah
# Processing Record 43 of Set 5 | xichang
# Processing Record 44 of Set 5 | kangaatsiaq
# Processing Record 45 of Set 5 | chuy
# Processing Record 46 of Set 5 | assiniboia
# Processing Record 47 of Set 5 | jibuti
# Processing Record 48 of Set 5 | kankon
# Processing Record 49 of Set 5 | benghazi
# Processing Record 50 of Set 5 | freeport
# Processing Record 1 of Set 6 | hernani
# Processing Record 2 of Set 6 | kaura namoda
# Processing Record 3 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 6 | rongcheng
# Processing Record 5 of Set 6 | bairiki
# Processing Record 6 of Set 6 | bardiyah
# Processing Record 7 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 6 | ayios andreas
# City not found. Skipping...
# Processing Record 9 of Set 6 | mocuba
# Processing Record 10 of Set 6 | huarmey
# Processing Record 11 of Set 6 | arlit
# Processing Record 12 of Set 6 | tabou
# Processing Record 13 of Set 6 | vostok
# Processing Record 14 of Set 6 | olafsvik
# Processing Record 15 of Set 6 | olinda
# Processing Record 16 of Set 6 | yinchuan
# Processing Record 17 of Set 6 | cravo norte
# Processing Record 18 of Set 6 | valparaiso
# Processing Record 19 of Set 6 | tecalitlan
# Processing Record 20 of Set 6 | avarua
# Processing Record 21 of Set 6 | lagoa
# Processing Record 22 of Set 6 | hovd
# Processing Record 23 of Set 6 | uvalde
# Processing Record 24 of Set 6 | faanui
# Processing Record 25 of Set 6 | chilca
# Processing Record 26 of Set 6 | dingle
# Processing Record 27 of Set 6 | altoona
# Processing Record 28 of Set 6 | san quintin
# Processing Record 29 of Set 6 | waipawa
# Processing Record 30 of Set 6 | harper
# Processing Record 31 of Set 6 | kismayo
# Processing Record 32 of Set 6 | giyani
# Processing Record 33 of Set 6 | heyang
# Processing Record 34 of Set 6 | faya
# Processing Record 35 of Set 6 | cidreira
# Processing Record 36 of Set 6 | rio gallegos
# Processing Record 37 of Set 6 | miraflores
# Processing Record 38 of Set 6 | cuiluan
# Processing Record 39 of Set 6 | halifax
# Processing Record 40 of Set 6 | nanortalik
# Processing Record 41 of Set 6 | urshelskiy
# Processing Record 42 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 6 | lavrentiya
# Processing Record 44 of Set 6 | leo
# Processing Record 45 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 46 of Set 6 | guaymas
# Processing Record 47 of Set 6 | independence
# Processing Record 48 of Set 6 | invermere
# Processing Record 49 of Set 6 | taoudenni
# Processing Record 50 of Set 6 | castro
# Processing Record 1 of Set 7 | mont-de-marsan
# Processing Record 2 of Set 7 | birao
# Processing Record 3 of Set 7 | hobyo
# Processing Record 4 of Set 7 | nagarote
# Processing Record 5 of Set 7 | valley city
# Processing Record 6 of Set 7 | alice town
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | ballina
# Processing Record 9 of Set 7 | jiamusi
# Processing Record 10 of Set 7 | hasaki
# Processing Record 11 of Set 7 | ahuimanu
# Processing Record 12 of Set 7 | sault sainte marie
# Processing Record 13 of Set 7 | nikolskoye
# Processing Record 14 of Set 7 | san ramon de la nueva oran
# Processing Record 15 of Set 7 | shimoda
# Processing Record 16 of Set 7 | yoichi
# Processing Record 17 of Set 7 | zhigansk
# Processing Record 18 of Set 7 | sussex
# Processing Record 19 of Set 7 | kushmurun
# Processing Record 20 of Set 7 | karwar
# Processing Record 21 of Set 7 | tezu
# Processing Record 22 of Set 7 | idukki
# Processing Record 23 of Set 7 | aklavik
# Processing Record 24 of Set 7 | wajir
# Processing Record 25 of Set 7 | sao filipe
# Processing Record 26 of Set 7 | phetchaburi
# Processing Record 27 of Set 7 | abha
# Processing Record 28 of Set 7 | mahebourg
# Processing Record 29 of Set 7 | williams lake
# Processing Record 30 of Set 7 | alta floresta
# Processing Record 31 of Set 7 | klichka
# Processing Record 32 of Set 7 | redmond
# Processing Record 33 of Set 7 | mariental
# Processing Record 34 of Set 7 | nieuw amsterdam
# Processing Record 35 of Set 7 | yining
# Processing Record 36 of Set 7 | geraldton
# Processing Record 37 of Set 7 | ilo
# Processing Record 38 of Set 7 | biltine
# Processing Record 39 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 40 of Set 7 | kanonji
# Processing Record 41 of Set 7 | trelew
# Processing Record 42 of Set 7 | teya
# Processing Record 43 of Set 7 | zhangjiakou
# Processing Record 44 of Set 7 | padang
# Processing Record 45 of Set 7 | camabatela
# Processing Record 46 of Set 7 | ostrovnoy
# Processing Record 47 of Set 7 | yumen
# Processing Record 48 of Set 7 | buta
# Processing Record 49 of Set 7 | eureka
# Processing Record 50 of Set 7 | novobirilyussy
# Processing Record 1 of Set 8 | hay river
# Processing Record 2 of Set 8 | abu samrah
# Processing Record 3 of Set 8 | nizwa
# Processing Record 4 of Set 8 | yarmouth
# Processing Record 5 of Set 8 | komsomolskiy
# Processing Record 6 of Set 8 | dublyany
# Processing Record 7 of Set 8 | ancud
# Processing Record 8 of Set 8 | penalva
# Processing Record 9 of Set 8 | dese
# Processing Record 10 of Set 8 | curuca
# Processing Record 11 of Set 8 | joshimath
# Processing Record 12 of Set 8 | veraval
# Processing Record 13 of Set 8 | hambantota
# Processing Record 14 of Set 8 | tromso
# Processing Record 15 of Set 8 | manokwari
# Processing Record 16 of Set 8 | krasnyy chikoy
# Processing Record 17 of Set 8 | miramar
# Processing Record 18 of Set 8 | ulaangom
# Processing Record 19 of Set 8 | burnie
# Processing Record 20 of Set 8 | praia
# Processing Record 21 of Set 8 | lipin bor
# Processing Record 22 of Set 8 | kenora
# Processing Record 23 of Set 8 | panjab
# Processing Record 24 of Set 8 | wachtebeke
# Processing Record 25 of Set 8 | thinadhoo
# Processing Record 26 of Set 8 | clyde river
# Processing Record 27 of Set 8 | kaeo
# Processing Record 28 of Set 8 | college
# Processing Record 29 of Set 8 | lufilufi
# Processing Record 30 of Set 8 | rajapur
# Processing Record 31 of Set 8 | camacha
# Processing Record 32 of Set 8 | nizhniy mamon
# Processing Record 33 of Set 8 | port lincoln
# Processing Record 34 of Set 8 | puro
# Processing Record 35 of Set 8 | pochutla
# Processing Record 36 of Set 8 | qatana
# Processing Record 37 of Set 8 | shingu
# Processing Record 38 of Set 8 | samana
# Processing Record 39 of Set 8 | gat
# Processing Record 40 of Set 8 | pardi
# Processing Record 41 of Set 8 | cristalina
# Processing Record 42 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 8 | grindavik
# Processing Record 44 of Set 8 | beipiao
# Processing Record 45 of Set 8 | katsuura
# Processing Record 46 of Set 8 | ngorongoro
# Processing Record 47 of Set 8 | tigil
# Processing Record 48 of Set 8 | lata
# Processing Record 49 of Set 8 | anaconda
# Processing Record 50 of Set 8 | saldanha
# Processing Record 1 of Set 9 | temiscaming
# Processing Record 2 of Set 9 | port hardy
# Processing Record 3 of Set 9 | ambovombe
# Processing Record 4 of Set 9 | bure
# Processing Record 5 of Set 9 | joensuu
# Processing Record 6 of Set 9 | morro bay
# Processing Record 7 of Set 9 | vanimo
# Processing Record 8 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 9 | shelton
# Processing Record 10 of Set 9 | chapleau
# Processing Record 11 of Set 9 | qingdao
# Processing Record 12 of Set 9 | suntar
# Processing Record 13 of Set 9 | zharkent
# Processing Record 14 of Set 9 | nampula
# Processing Record 15 of Set 9 | chernyshevskiy
# Processing Record 16 of Set 9 | puerto del rosario
# Processing Record 17 of Set 9 | vorotynets
# Processing Record 18 of Set 9 | palmer
# Processing Record 19 of Set 9 | torbay
# Processing Record 20 of Set 9 | peleduy
# Processing Record 21 of Set 9 | hami
# Processing Record 22 of Set 9 | iwanai
# Processing Record 23 of Set 9 | vestmanna
# Processing Record 24 of Set 9 | fairbanks
# Processing Record 25 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 26 of Set 9 | brae
# Processing Record 27 of Set 9 | fortuna
# Processing Record 28 of Set 9 | mutata
# Processing Record 29 of Set 9 | anito
# Processing Record 30 of Set 9 | vaovai
# City not found. Skipping...
# Processing Record 31 of Set 9 | ambon
# Processing Record 32 of Set 9 | saint george
# Processing Record 33 of Set 9 | bati
# Processing Record 34 of Set 9 | severo-yeniseyskiy
# Processing Record 35 of Set 9 | atsipopoulon
# Processing Record 36 of Set 9 | khanpur
# Processing Record 37 of Set 9 | ati
# Processing Record 38 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 39 of Set 9 | kant
# Processing Record 40 of Set 9 | kruisfontein
# Processing Record 41 of Set 9 | bilma
# Processing Record 42 of Set 9 | mahon
# Processing Record 43 of Set 9 | deyang
# Processing Record 44 of Set 9 | codrington
# Processing Record 45 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 46 of Set 9 | pedasi
# Processing Record 47 of Set 9 | luderitz
# Processing Record 48 of Set 9 | grand-santi
# Processing Record 49 of Set 9 | okato
# Processing Record 50 of Set 9 | torrijos
# Processing Record 1 of Set 10 | mizan teferi
# Processing Record 2 of Set 10 | devonport
# Processing Record 3 of Set 10 | kidal
# Processing Record 4 of Set 10 | kaseda
# Processing Record 5 of Set 10 | norman wells
# Processing Record 6 of Set 10 | pishin
# Processing Record 7 of Set 10 | ciudad bolivar
# Processing Record 8 of Set 10 | east moline
# Processing Record 9 of Set 10 | san carlos de bariloche
# Processing Record 10 of Set 10 | boa vista
# Processing Record 11 of Set 10 | berlevag
# Processing Record 12 of Set 10 | wattegama
# Processing Record 13 of Set 10 | storslett
# Processing Record 14 of Set 10 | dhidhdhoo
# Processing Record 15 of Set 10 | kato mazarakion
# Processing Record 16 of Set 10 | buala
# Processing Record 17 of Set 10 | faratsiho
# Processing Record 18 of Set 10 | cabedelo
# Processing Record 19 of Set 10 | brunswick
# Processing Record 20 of Set 10 | paamiut
# Processing Record 21 of Set 10 | zhezkazgan
# Processing Record 22 of Set 10 | batsfjord
# Processing Record 23 of Set 10 | sola
# Processing Record 24 of Set 10 | iracoubo
# Processing Record 25 of Set 10 | kihei
# Processing Record 26 of Set 10 | pemangkat
# Processing Record 27 of Set 10 | mount gambier
# Processing Record 28 of Set 10 | puerto maldonado
# Processing Record 29 of Set 10 | isiro
# Processing Record 30 of Set 10 | kalcheva
# Processing Record 31 of Set 10 | aracati
# Processing Record 32 of Set 10 | praia da vitoria
# Processing Record 33 of Set 10 | narsaq
# Processing Record 34 of Set 10 | opuwo
# Processing Record 35 of Set 10 | mamallapuram
# Processing Record 36 of Set 10 | auburndale
# Processing Record 37 of Set 10 | san pedro
# Processing Record 38 of Set 10 | ridgecrest
# Processing Record 39 of Set 10 | krasnoshchekovo
# Processing Record 40 of Set 10 | rio pardo
# Processing Record 41 of Set 10 | mayya
# Processing Record 42 of Set 10 | iquique
# Processing Record 43 of Set 10 | gottingen
# Processing Record 44 of Set 10 | dicabisagan
# Processing Record 45 of Set 10 | voh
# Processing Record 46 of Set 10 | elizabeth city
# Processing Record 47 of Set 10 | juneau
# Processing Record 48 of Set 10 | gualaquiza
# Processing Record 49 of Set 10 | nizhniy tsasuchey
# Processing Record 50 of Set 10 | camana
# Processing Record 1 of Set 11 | victoria
# Processing Record 2 of Set 11 | maldonado
# Processing Record 3 of Set 11 | ternate
# Processing Record 4 of Set 11 | san patricio
# Processing Record 5 of Set 11 | terra rica
# Processing Record 6 of Set 11 | grand gaube
# Processing Record 7 of Set 11 | cuamba
# Processing Record 8 of Set 11 | ullapool
# Processing Record 9 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 10 of Set 11 | constitucion
# Processing Record 11 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 11 | sambava
# Processing Record 13 of Set 11 | srednekolymsk
# Processing Record 14 of Set 11 | dushanbe
# Processing Record 15 of Set 11 | baghdad
# Processing Record 16 of Set 11 | senica
# Processing Record 17 of Set 11 | waingapu
# Processing Record 18 of Set 11 | port-gentil
# Processing Record 19 of Set 11 | bud
# Processing Record 20 of Set 11 | stornoway
# Processing Record 21 of Set 11 | hualmay
# Processing Record 22 of Set 11 | la libertad
# Processing Record 23 of Set 11 | severomuysk
# Processing Record 24 of Set 11 | araouane
# Processing Record 25 of Set 11 | kuala terengganu
# Processing Record 26 of Set 11 | wilmington
# Processing Record 27 of Set 11 | oume
# Processing Record 28 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 29 of Set 11 | naron
# Processing Record 30 of Set 11 | ginir
# Processing Record 31 of Set 11 | cap-aux-meules
# Processing Record 32 of Set 11 | pachino
# Processing Record 33 of Set 11 | wilmington island
# Processing Record 34 of Set 11 | okakarara
# Processing Record 35 of Set 11 | lamar
# Processing Record 36 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 11 | sechura
# Processing Record 38 of Set 11 | oranjemund
# Processing Record 39 of Set 11 | bathsheba
# Processing Record 40 of Set 11 | savannah bight
# Processing Record 41 of Set 11 | graaff-reinet
# Processing Record 42 of Set 11 | elbistan
# Processing Record 43 of Set 11 | sitka
# Processing Record 44 of Set 11 | muisne
# Processing Record 45 of Set 11 | saint-joseph
# Processing Record 46 of Set 11 | dongsheng
# Processing Record 47 of Set 11 | comodoro rivadavia
# Processing Record 48 of Set 11 | jambi
# Processing Record 49 of Set 11 | buchanan
# Processing Record 50 of Set 11 | ongandjera
# Processing Record 1 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 2 of Set 12 | macusani
# Processing Record 3 of Set 12 | alamosa
# Processing Record 4 of Set 12 | saint-pierre
# Processing Record 5 of Set 12 | tabuk
# Processing Record 6 of Set 12 | espanola
# Processing Record 7 of Set 12 | mongoumba
# Processing Record 8 of Set 12 | kudahuvadhoo
# Processing Record 9 of Set 12 | flin flon
# Processing Record 10 of Set 12 | vila praia de ancora
# Processing Record 11 of Set 12 | mugur-aksy
# Processing Record 12 of Set 12 | tongzi
# Processing Record 13 of Set 12 | tallahassee
# Processing Record 14 of Set 12 | talara
# Processing Record 15 of Set 12 | bonavista
# Processing Record 16 of Set 12 | kongolo
# Processing Record 17 of Set 12 | orikum
# Processing Record 18 of Set 12 | pimentel
# Processing Record 19 of Set 12 | buluang
# Processing Record 20 of Set 12 | anchorage
# Processing Record 21 of Set 12 | sur
# Processing Record 22 of Set 12 | dombarovskiy
# Processing Record 23 of Set 12 | aranos
# Processing Record 24 of Set 12 | les cayes
# Processing Record 25 of Set 12 | tual
# Processing Record 26 of Set 12 | erzin
# Processing Record 27 of Set 12 | beringovskiy
# Processing Record 28 of Set 12 | kolyvan
# Processing Record 29 of Set 12 | jaswantnagar
# Processing Record 30 of Set 12 | tessaoua
# Processing Record 31 of Set 12 | newcastle
# Processing Record 32 of Set 12 | al
# City not found. Skipping...
# Processing Record 33 of Set 12 | sabang
# Processing Record 34 of Set 12 | panzhihua
# Processing Record 35 of Set 12 | vagay
# Processing Record 36 of Set 12 | alofi
# Processing Record 37 of Set 12 | beloha
# Processing Record 38 of Set 12 | anadyr
# Processing Record 39 of Set 12 | kapit
# Processing Record 40 of Set 12 | khoy
# Processing Record 41 of Set 12 | canutama
# Processing Record 42 of Set 12 | plettenberg bay
# Processing Record 43 of Set 12 | kilvelur
# Processing Record 44 of Set 12 | estacion coahuila
# Processing Record 45 of Set 12 | pag
# Processing Record 46 of Set 12 | villa carlos paz
# Processing Record 47 of Set 12 | koslan
# Processing Record 48 of Set 12 | laem sing
# Processing Record 49 of Set 12 | te anau
# Processing Record 50 of Set 12 | chengde
# Processing Record 1 of Set 13 | mattersburg
# Processing Record 2 of Set 13 | marzuq
# Processing Record 3 of Set 13 | ludvika
# Processing Record 4 of Set 13 | piacabucu
# Processing Record 5 of Set 13 | kuala lumpur
# Processing Record 6 of Set 13 | peniche
# Processing Record 7 of Set 13 | mahdasht
# Processing Record 8 of Set 13 | salalah
# Processing Record 9 of Set 13 | dunga bunga
# Processing Record 10 of Set 13 | la asuncion
# Processing Record 11 of Set 13 | burica
# City not found. Skipping...
# Processing Record 12 of Set 13 | baykit
# Processing Record 13 of Set 13 | zarand
# Processing Record 14 of Set 13 | port saint lucie
# Processing Record 15 of Set 13 | mahadday weyne
# City not found. Skipping...
# Processing Record 16 of Set 13 | maryville
# Processing Record 17 of Set 13 | nome
# Processing Record 18 of Set 13 | tombouctou
# Processing Record 19 of Set 13 | haverfordwest
# Processing Record 20 of Set 13 | poso
# Processing Record 21 of Set 13 | arras
# Processing Record 22 of Set 13 | awbari
# Processing Record 23 of Set 13 | vieques
# Processing Record 24 of Set 13 | kurumkan
# Processing Record 25 of Set 13 | saint-augustin
# Processing Record 26 of Set 13 | saint-louis
# Processing Record 27 of Set 13 | bambanglipuro
# Processing Record 28 of Set 13 | half moon bay
# Processing Record 29 of Set 13 | vila velha
# Processing Record 30 of Set 13 | kasamwa
# Processing Record 31 of Set 13 | gizo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 590

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Hermanus -34.4187   19.2345     52.81        80          64       11.07
# 1  New Norfolk -42.7826  147.0587     47.71        75          27        3.85
# 2      Rikitea -23.1203 -134.9692     73.49        72          20       11.63
# 3       Albany  42.6001  -73.9662     64.81        66         100        2.24
# 4   Kaitangata -46.2817  169.8464     48.92        68          18        5.59
# 5      Sorland  67.6670   12.6934     51.66        73         100       12.41
# 6   Port Blair  11.6667   92.7500     78.84        89          75        2.30
# 7   Naryan-Mar  67.6713   53.0870     37.35        96          99        8.95
# 8        Tiksi  71.6872  128.8694     18.77        89         100       12.37
# 9       Hobart -42.8794  147.3294     48.06        83          40        8.05
#
#   Country Current Description
# 0      ZA       broken clouds
# 1      AU    scattered clouds
# 2      PF          few clouds
# 3      US     overcast clouds
# 4      NZ          few clouds
# 5      NO     overcast clouds
# 6      IN                mist
# 7      RU     overcast clouds
# 8      RU     overcast clouds
# 9      AU    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country","Lat","Lng","Max Temp", "Humidity","Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_reorder_df = city_data_df[new_column_order]

# Display sample data
city_data_reorder_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Hermanus      ZA -34.4187   19.2345     52.81        80          64
# 1      New Norfolk      AU -42.7826  147.0587     47.71        75          27
# 2          Rikitea      PF -23.1203 -134.9692     73.49        72          20
# 3           Albany      US  42.6001  -73.9662     64.81        66         100
# 4       Kaitangata      NZ -46.2817  169.8464     48.92        68          18
# ..             ...     ...      ...       ...       ...       ...         ...
# 585  Bambanglipuro      ID  -7.9500  110.2833     76.80        90          99
# 586  Half Moon Bay      US  37.4636 -122.4286     79.57        73         100
# 587     Vila Velha      BR -20.3297  -40.2925     73.35        77          40
# 588        Kasamwa      TZ  -2.8500   32.4333     68.02        77          16
# 589           Gizo      SB  -8.1030  156.8419     82.74        70          22
#
#      Wind Speed Current Description
# 0         11.07       broken clouds
# 1          3.85    scattered clouds
# 2         11.63          few clouds
# 3          2.24     overcast clouds
# 4          5.59          few clouds
# ..          ...                 ...
# 585        5.14     overcast clouds
# 586        9.22     overcast clouds
# 587        6.91    scattered clouds
# 588        3.27          few clouds
# 589        4.76          light rain
#
# [590 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_reorder_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_reorder_df.to_csv(output_data_file, index_label="City_ID")
